# %% [markdown]
# **NOTE:** I haven't found any library to generate inflected forms from the lemma for Catalan. The best I could do was to use the vocabulary stored into a SpaCy model.

# %%
import pandas as pd
import spacy

# %%
# Get data fom file
df = pd.read_csv("Catalan_Stems.txt", sep=";")

# %%
# The dataset contains the keywords in the lexicon, the stems and POS tag
df.head()
# Out:
#   Lemma_Catalan Stem_Catalan POS_Catalan
# 0        amagar         amag        VERB
# 1          amic         amic        NOUN
# 2          amic         amig        NOUN
# 3       arxivar        arxiv        VERB
# 4        blocar         bloc        VERB

# %%
# We load a Catalan language model from SpaCy
nlp = spacy.load("ca_core_news_md")

# %%
# Searches each of the stems of the lexicon in the vocabulary of the model
# Then lemmatises all the forms found and keeps only those forms whose lemmas and POS tag correspond to the keywords in the lexicon
# Saves the lemma, inflected form and morphological features in a tuple (one tuple for each inflected form)
# Saves the tuples into a new list to create a DF later
def get_inflections(stem, lemma, pos):
    # Using regex, find all forms that have the stem in the model's vocabulary
    forms = []
    for w in nlp.vocab.strings:
        if w.startswith(stem):
            #print(w)
            forms.append(w)
    # Lemmatise and filter the forms to keep only the ones that have the lemma as indicated in the input
    # We save form, lemma, POS and inflection info
    lemmas = []
    for w in forms:
        doc = nlp(w)
        if doc[0].pos_ == pos and doc[0].lemma_ == lemma:
            #print(doc[0].text, doc[0].lemma_, doc[0].pos_, doc[0].morph)
            lemmas.append((doc[0].lemma_, doc[0].text, doc[0].pos_, doc[0].morph))
    # Remove duplicates before returning the list
    return list(set(lemmas))

# %%
# Example with the keyword 'comentar' and stem 'coment'
infl = get_inflections('coment', 'comentar', 'VERB')
infl[:5]
# Out:
# [('comentar',
#   'comentava',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin),
#  ('comentar',
#   'comentaven',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Imp|VerbForm=Fin),
#  ('comentar',
#   'comentaràs',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=1|Tense=Pres|VerbForm=Fin),
#  ('comentar',
#   'comentaré',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=1|Tense=Fut|VerbForm=Fin),
#  ('comentar',
#   'comentarem',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=1|Tense=Fut|VerbForm=Fin)]

# %%
# Test with a row of the DF
infl = []

for index, row in df.iterrows():
    if index < 3:
        print(row['Stem_Catalan'], row['Lemma_Catalan'], row['POS_Catalan'])
        tmp = get_inflections(row['Stem_Catalan'], row['Lemma_Catalan'], row['POS_Catalan'])
        print(f'Index: {index} - Value: {len(tmp)}')
# Out:
# amag amagar VERB
# Index: 0 - Value: 19
# amic amic NOUN
# Index: 1 - Value: 2
# amig amic NOUN
# Index: 2 - Value: 2

# %%
# Apply inflection function to all rows of the DF - returns none because it fills the list infl_list
infl_list = []
df.apply(lambda row: infl_list.extend(get_inflections(row['Stem_Catalan'], row['Lemma_Catalan'], row['POS_Catalan'])), axis=1)
# Out:
# 0     None
# 1     None
# 2     None
# 3     None
# 4     None
#       ...
# 56    None
# 57    None
# 58    None
# 59    None
# 60    None
# Length: 61, dtype: object

# %%
infl_list
# Out:
# [('amagar',
#   'amagaren',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin),
#  ('amagar',
#   'amagaré',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=1|Tense=Fut|VerbForm=Fin),
#  ('amagar',
#   'amagava',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin),
#  ('amagar',
#   'amagarien',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Imp|VerbForm=Fin),
#  ('amagar',
#   'amagarà',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Fut|VerbForm=Fin),
#  ('amagar',
#   'amagaran',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Fut|VerbForm=Fin),
#  ('amagar',
#   'amaga',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin),
#  ('amagar', 'amagant', 'VERB', VerbForm=Ger),
#  ('amagar',
#   'amagam',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin),
#  ('amagar',
#   'amagàvem',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=1|Tense=Imp|VerbForm=Fin),
#  ('amagar',
#   'amag',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin),
#  ('amagar',
#   'amague',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin),
#  ('amagar',
#   'amagà',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin),
#  ('amagar',
#   'amagaven',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Imp|VerbForm=Fin),
#  ('amagar',
#   'amagarem',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=1|Tense=Fut|VerbForm=Fin),
#  ('amagar',
#   'amagen',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin),
#  ('amagar',
#   'amago',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin),
#  ('amagar', 'amagar', 'VERB', VerbForm=Inf),
#  ('amagar', 'amagaria', 'VERB', Mood=Cnd|Number=Sing|Person=3|VerbForm=Fin),
#  ('amic', 'amic', 'NOUN', Gender=Masc|Number=Sing),
#  ('amic', 'amics', 'NOUN', Gender=Masc|Number=Plur),
#  ('amic', 'amiga', 'NOUN', Gender=Fem|Number=Sing),
#  ('amic', 'amigues', 'NOUN', Gender=Fem|Number=Plur),
#  ('arxivar',
#   'arxivessin',
#   'VERB',
#   Mood=Sub|Number=Plur|Person=3|Tense=Imp|VerbForm=Fin),
#  ('arxivar', 'arxivant', 'VERB', VerbForm=Ger),
#  ('arxivar',
#   'arxivarà',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Fut|VerbForm=Fin),
#  ('arxivar',
#   'arxivaran',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Fut|VerbForm=Fin),
#  ('arxivar', 'arxivar', 'VERB', VerbForm=Inf),
#  ('arxivar',
#   'arxivaven',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Imp|VerbForm=Fin),
#  ('arxivar',
#   'arxivava',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin),
#  ('arxivar',
#   'arxiven',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Imp|VerbForm=Fin),
#  ('blocar',
#   'blocava',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin),
#  ('blocar', 'blocar', 'VERB', VerbForm=Inf),
#  ('blocar', 'blocant', 'VERB', VerbForm=Ger),
#  ('blocar',
#   'bloca',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin),
#  ('bloquejar',
#   'bloquejarem',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=1|Tense=Fut|VerbForm=Fin),
#  ('bloquejar',
#   'bloquejaren',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin),
#  ('bloquejar',
#   'bloquejarà',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Fut|VerbForm=Fin),
#  ('bloquejar',
#   'bloquejat',
#   'VERB',
#   Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part),
#  ('bloquejar',
#   'bloquege',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin),
#  ('bloquejar',
#   'bloquejava',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin),
#  ('bloquejar', 'bloquejant', 'VERB', VerbForm=Inf),
#  ('bloquejar', 'bloquejen', 'VERB', VerbForm=Inf),
#  ('bloquejar', 'bloquejar', 'VERB', VerbForm=Inf),
#  ('bloquejar',
#   'bloquejaran',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Fut|VerbForm=Fin),
#  ('bloquejar',
#   'bloquejaria',
#   'VERB',
#   Mood=Cnd|Number=Sing|Person=3|VerbForm=Fin),
#  ('bloquejar',
#   'bloquejaven',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Imp|VerbForm=Fin),
#  ('bloquejar',
#   'bloquejarien',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Imp|VerbForm=Fin),
#  ('bloquejar',
#   'bloqueja',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin),
#  ('bloquejar', 'bloquejant', 'VERB', VerbForm=Ger),
#  ('canal', 'canal', 'NOUN', Gender=Fem|Number=Sing),
#  ('canal', 'canals', 'NOUN', Gender=Masc|Number=Plur),
#  ('clavar',
#   'clavaven',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Imp|VerbForm=Fin),
#  ('clavar',
#   'clava',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin),
#  ('clavar',
#   'clavaré',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin),
#  ('clavar',
#   'clavaran',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Fut|VerbForm=Fin),
#  ('clavar',
#   'clavem',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=1|Tense=Imp|VerbForm=Fin),
#  ('clavar', 'clavaria', 'VERB', Mood=Cnd|Number=Sing|Person=3|VerbForm=Fin),
#  ('clavar',
#   'claven',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Imp|VerbForm=Fin),
#  ('clavar', 'clavo', 'VERB', VerbForm=Inf),
#  ('clavar',
#   'clavessin',
#   'VERB',
#   Mood=Sub|Number=Plur|Person=3|Tense=Imp|VerbForm=Fin),
#  ('clavar', 'clavés', 'VERB', VerbForm=Inf),
#  ('clavar', 'clavar', 'VERB', VerbForm=Inf),
#  ('clavar', 'clavant', 'VERB', VerbForm=Ger),
#  ('clavar',
#   'clavava',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin),
#  ('clavar',
#   'clavarem',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=1|Tense=Fut|VerbForm=Fin),
#  ('clavar', 'clavà', 'VERB', VerbForm=Inf),
#  ('clavar',
#   'clavaren',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin),
#  ('clavar',
#   'clavarà',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Fut|VerbForm=Fin),
#  ('comentar',
#   'comentés',
#   'VERB',
#   Mood=Sub|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin),
#  ('comentar',
#   'comentaves',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin),
#  ('comentar',
#   'comenteu',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin),
#  ('comentar',
#   'comente',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin),
#  ('comentar', 'comentéssiu', 'VERB', VerbForm=Inf),
#  ('comentar', 'comentant', 'VERB', VerbForm=Ger),
#  ('comentar',
#   'comentem',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=1|Tense=Pres|VerbForm=Fin),
#  ('comentar',
#   'comentaran',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Fut|VerbForm=Fin),
#  ('comentar',
#   'comentam',
#   'VERB',
#   Mood=Sub|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin),
#  ('comentar', 'comentar', 'VERB', VerbForm=Inf),
#  ('comentar',
#   'comenti',
#   'VERB',
#   Mood=Sub|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin),
#  ('comentar',
#   'comentaràs',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=1|Tense=Pres|VerbForm=Fin),
#  ('comentar',
#   'comenten',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin),
#  ('comentar',
#   'comentarà',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Fut|VerbForm=Fin),
#  ('comentar',
#   'comentàvem',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=1|Tense=Imp|VerbForm=Fin),
#  ('comentar',
#   'comentareu',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin),
#  ('comentar',
#   'comentaven',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Imp|VerbForm=Fin),
#  ('comentar',
#   'comentarem',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=1|Tense=Fut|VerbForm=Fin),
#  ('comentar', 'comentessis', 'VERB', VerbForm=Inf),
#  ('comentar',
#   'comentàrem',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=1|Tense=Fut|VerbForm=Fin),
#  ('comentar',
#   'comentaré',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=1|Tense=Fut|VerbForm=Fin),
#  ('comentar',
#   'comentava',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin),
#  ('comentar',
#   'comento',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin),
#  ('comentar',
#   'comentessin',
#   'VERB',
#   Mood=Sub|Number=Plur|Person=3|Tense=Imp|VerbForm=Fin),
#  ('comentar',
#   'comentàveu',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin),
#  ('comentar', 'comentà', 'VERB', Mood=Cnd|Number=Sing|Person=1|VerbForm=Fin),
#  ('comentar',
#   'comenta',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin),
#  ('comentar',
#   'comentaren',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin),
#  ('comentar',
#   'comentes',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin),
#  ('comentar',
#   'comentat',
#   'VERB',
#   Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part),
#  ('comentari', 'comentaris', 'NOUN', Gender=Masc|Number=Plur),
#  ('comentari', 'comentari', 'NOUN', Gender=Masc|Number=Sing),
#  ('compartir',
#   'compartírem',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=1|Tense=Fut|VerbForm=Fin),
#  ('compartir',
#   'comparteixen',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin),
#  ('compartir',
#   'compartiu',
#   'VERB',
#   Mood=Cnd|Number=Plur|Person=1|VerbForm=Fin),
#  ('compartir',
#   'compartix',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin),
#  ('compartir',
#   'compartien',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Imp|VerbForm=Fin),
#  ('compartir', 'compartint', 'VERB', VerbForm=Ger),
#  ('compartir',
#   'compartirien',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin),
#  ('compartir',
#   'compartissis',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin),
#  ('compartir',
#   'compartiren',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin),
#  ('compartir',
#   'compartin',
#   'VERB',
#   Mood=Sub|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin),
#  ('compartir',
#   'compartiran',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Fut|VerbForm=Fin),
#  ('compartir',
#   'comparteixo',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin),
#  ('compartir',
#   'compartirà',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Fut|VerbForm=Fin),
#  ('compartir',
#   'compartiré',
#   'VERB',
#   Mood=Sub|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin),
#  ('compartir',
#   'compartiu',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=1|Tense=Imp|VerbForm=Fin),
#  ('compartir',
#   'compartia',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin),
#  ('compartir', 'compartir', 'VERB', VerbForm=Inf),
#  ('compartir',
#   'compartiràs',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=1|Tense=Pres|VerbForm=Fin),
#  ('compartir',
#   'compartiríem',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=1|Tense=Imp|VerbForm=Fin),
#  ('compartir',
#   'compartissin',
#   'VERB',
#   Mood=Sub|Number=Plur|Person=3|Tense=Imp|VerbForm=Fin),
#  ('compartir',
#   'comparteixi',
#   'VERB',
#   Mood=Sub|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin),
#  ('compartir',
#   'comparteix',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin),
#  ('compartir',
#   'compartisc',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin),
#  ('compartir',
#   'compartíssim',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=1|Tense=Pres|VerbForm=Fin),
#  ('compartir',
#   'compartíem',
#   'VERB',
#   Mood=Cnd|Number=Plur|Person=1|VerbForm=Fin),
#  ('compartir',
#   'compartís',
#   'VERB',
#   Mood=Sub|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin),
#  ('compartir',
#   'compartiria',
#   'VERB',
#   Mood=Cnd|Number=Sing|Person=3|VerbForm=Fin),
#  ('compartir', 'compartireu', 'VERB', VerbForm=Ger),
#  ('compartir',
#   'comparteixis',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin),
#  ('compartir',
#   'compartim',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=1|Tense=Pres|VerbForm=Fin),
#  ('compartir',
#   'comparteixin',
#   'VERB',
#   Mood=Sub|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin),
#  ('compartir',
#   'compartirem',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=1|Tense=Fut|VerbForm=Fin),
#  ('compartir',
#   'comparteixes',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=2|Tense=Pres|VerbForm=Fin),
#  ('compartir',
#   'compartesc',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin),
#  ('compartir',
#   'compartírem',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=1|Tense=Fut|VerbForm=Fin),
#  ('compartir',
#   'comparteixen',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin),
#  ('compartir',
#   'compartiu',
#   'VERB',
#   Mood=Cnd|Number=Plur|Person=1|VerbForm=Fin),
#  ('compartir',
#   'compartix',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin),
#  ('compartir',
#   'compartien',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Imp|VerbForm=Fin),
#  ('compartir', 'compartint', 'VERB', VerbForm=Ger),
#  ('compartir',
#   'compartirien',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin),
#  ('compartir',
#   'compartissis',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin),
#  ('compartir',
#   'compartiren',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin),
#  ('compartir',
#   'compartin',
#   'VERB',
#   Mood=Sub|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin),
#  ('compartir',
#   'compartiran',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Fut|VerbForm=Fin),
#  ('compartir',
#   'comparteixo',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin),
#  ('compartir',
#   'compartirà',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Fut|VerbForm=Fin),
#  ('compartir',
#   'compartiré',
#   'VERB',
#   Mood=Sub|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin),
#  ('compartir',
#   'compartiu',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=1|Tense=Imp|VerbForm=Fin),
#  ('compartir',
#   'compartia',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin),
#  ('compartir', 'compartir', 'VERB', VerbForm=Inf),
#  ('compartir',
#   'compartiràs',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=1|Tense=Pres|VerbForm=Fin),
#  ('compartir',
#   'compartiríem',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=1|Tense=Imp|VerbForm=Fin),
#  ('compartir',
#   'compartissin',
#   'VERB',
#   Mood=Sub|Number=Plur|Person=3|Tense=Imp|VerbForm=Fin),
#  ('compartir',
#   'comparteixi',
#   'VERB',
#   Mood=Sub|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin),
#  ('compartir',
#   'comparteix',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin),
#  ('compartir',
#   'compartisc',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin),
#  ('compartir',
#   'compartíssim',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=1|Tense=Pres|VerbForm=Fin),
#  ('compartir',
#   'compartíem',
#   'VERB',
#   Mood=Cnd|Number=Plur|Person=1|VerbForm=Fin),
#  ('compartir',
#   'compartís',
#   'VERB',
#   Mood=Sub|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin),
#  ('compartir',
#   'compartiria',
#   'VERB',
#   Mood=Cnd|Number=Sing|Person=3|VerbForm=Fin),
#  ('compartir', 'compartireu', 'VERB', VerbForm=Ger),
#  ('compartir',
#   'comparteixis',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin),
#  ('compartir',
#   'compartim',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=1|Tense=Pres|VerbForm=Fin),
#  ('compartir',
#   'comparteixin',
#   'VERB',
#   Mood=Sub|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin),
#  ('compartir',
#   'compartirem',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=1|Tense=Fut|VerbForm=Fin),
#  ('compartir',
#   'comparteixes',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=2|Tense=Pres|VerbForm=Fin),
#  ('compartir',
#   'compartesc',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin),
#  ('compte', 'compte', 'NOUN', Gender=Masc|Number=Sing),
#  ('compte', 'comptes', 'NOUN', Gender=Masc|Number=Plur),
#  ('cronologia', 'cronologies', 'NOUN', Gender=Fem|Number=Plur),
#  ('cronologia', 'cronologia', 'NOUN', Gender=Fem|Number=Sing),
#  ('denunciar',
#   'denunciarem',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=1|Tense=Fut|VerbForm=Fin),
#  ('denunciar', 'denunciar', 'VERB', VerbForm=Inf),
#  ('denunciar',
#   'denuncien',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin),
#  ('denunciar',
#   'denunciïn',
#   'VERB',
#   Mood=Sub|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin),
#  ('denunciar',
#   'denunciaré',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Fut|VerbForm=Fin),
#  ('denunciar',
#   'denunciava',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin),
#  ('denunciar', 'denunciant', 'VERB', VerbForm=Ger),
#  ('denunciar',
#   'denuncie',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin),
#  ('denunciar',
#   'denuncieu',
#   'VERB',
#   Mood=Sub|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin),
#  ('denunciar', 'denuncià', 'VERB', VerbForm=Inf),
#  ('denunciar',
#   'denunciïs',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin),
#  ('denunciar',
#   'denunciés',
#   'VERB',
#   Mood=Sub|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin),
#  ('denunciar',
#   'denuncia',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin),
#  ('denunciar',
#   'denunciàrem',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Fut|VerbForm=Fin),
#  ('denunciar',
#   'denuncii',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin),
#  ('denunciar',
#   'denunciam',
#   'VERB',
#   Mood=Sub|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin),
#  ('denunciar',
#   'denunciem',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=1|Tense=Pres|VerbForm=Fin),
#  ('denunciar',
#   'denunciaria',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin),
#  ('denunciar',
#   'denunciada',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin),
#  ('denunciar',
#   'denunciaren',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin),
#  ('denunciar',
#   'denunciessin',
#   'VERB',
#   Mood=Sub|Number=Plur|Person=3|Tense=Imp|VerbForm=Fin),
#  ('denunciar',
#   'denunciarien',
#   'VERB',
#   Mood=Cnd|Number=Plur|Person=3|VerbForm=Fin),
#  ('denunciar',
#   'denuncií',
#   'VERB',
#   Mood=Sub|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin),
#  ('denunciar',
#   'denunciaran',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Fut|VerbForm=Fin),
#  ('denunciar',
#   'denunciarà',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Fut|VerbForm=Fin),
#  ('denunciar',
#   'denunciaven',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Imp|VerbForm=Fin),
#  ('denunciar',
#   'denunciàvem',
#   'VERB',
#   Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part),
#  ('denunciar',
#   'denunciï',
#   'VERB',
#   Mood=Sub|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin),
#  ('denunciar',
#   'denuncio',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin),
#  ('enviar',
#   'enviaven',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Imp|VerbForm=Fin),
#  ('enviar',
#   'enviam',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Fut|VerbForm=Fin),
#  ('enviar',
#   'enviéssim',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin),
#  ('enviar',
#   'envií',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Fut|VerbForm=Fin),
#  ('enviar',
#   'enviau',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Fut|VerbForm=Fin),
#  ('enviar', 'envie', 'VERB', VerbForm=Inf),
#  ('enviar',
#   'enviessin',
#   'VERB',
#   Mood=Sub|Number=Plur|Person=3|Tense=Imp|VerbForm=Fin),
#  ('enviar',
#   'enviés',
#   'VERB',
#   Mood=Sub|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin),
#  ('enviar',
#   'envio',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Fut|VerbForm=Fin),
#  ('enviar',
#   'enviessis',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin),
#  ('enviar',
#   'enviaré',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=1|Tense=Fut|VerbForm=Fin),
#  ('enviar',
#   'envii',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin),
#  ('enviar',
#   'enviava',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin),
#  ('enviar', 'enviar', 'VERB', VerbForm=Inf),
#  ('enviar',
#   'enviarà',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Fut|VerbForm=Fin),
#  ('enviar',
#   'enviarem',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=1|Tense=Fut|VerbForm=Fin),
#  ('enviar',
#   'enviaren',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin),
#  ('enviar',
#   'enviïs',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=1|Tense=Fut|VerbForm=Fin),
#  ('enviar',
#   'enviaríem',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=1|Tense=Imp|VerbForm=Fin),
#  ('enviar', 'envià', 'VERB', VerbForm=Inf),
#  ('enviar',
#   'enviaràs',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin),
#  ('enviar', 'envieu', 'VERB', VerbForm=Ger),
#  ('enviar',
#   'envieu',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin),
#  ('enviar', 'enviant', 'VERB', VerbForm=Ger),
#  ('enviar', 'enviaria', 'VERB', Mood=Cnd|Number=Sing|Person=3|VerbForm=Fin),
#  ('enviar',
#   'enviàvem',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=1|Tense=Pres|VerbForm=Fin),
#  ('enviar', 'enviàs', 'VERB', VerbForm=Inf),
#  ('enviar',
#   'enviaran',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Fut|VerbForm=Fin),
#  ('enviar',
#   'envieu',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=1|Tense=Pres|VerbForm=Fin),
#  ('enviar',
#   'envieu',
#   'VERB',
#   Mood=Sub|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin),
#  ('enviar',
#   'enviis',
#   'VERB',
#   Mood=Sub|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin),
#  ('enviar',
#   'enviàrem',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=1|Tense=Fut|VerbForm=Fin),
#  ('enviar',
#   'enviï',
#   'VERB',
#   Mood=Sub|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin),
#  ('enviar',
#   'enviem',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=1|Tense=Pres|VerbForm=Fin),
#  ('enviar',
#   'envia',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin),
#  ('enviar',
#   'envien',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin),
#  ('enviar',
#   'enviïn',
#   'VERB',
#   Mood=Sub|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin),
#  ('enviar',
#   'enviarien',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Imp|VerbForm=Fin),
#  ('enviar', 'envieu', 'VERB', VerbForm=Inf),
#  ('enviar',
#   'enviareu',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin),
#  ('esborrar',
#   'esborren',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin),
#  ('esborrar', 'esborris', 'VERB', VerbForm=Inf),
#  ('esborrar',
#   'esborraran',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Fut|VerbForm=Fin),
#  ('esborrar',
#   'esborrarem',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=1|Tense=Fut|VerbForm=Fin),
#  ('esborrar',
#   'esborra',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin),
#  ('esborrar',
#   'esborrava',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin),
#  ('esborrar', 'esborrar', 'VERB', VerbForm=Inf),
#  ('esborrar',
#   'esborressin',
#   'VERB',
#   Mood=Sub|Number=Plur|Person=3|Tense=Imp|VerbForm=Fin),
#  ('esborrar',
#   'esborraria',
#   'VERB',
#   Mood=Cnd|Number=Sing|Person=3|VerbForm=Fin),
#  ('esborrar',
#   'esborraven',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Imp|VerbForm=Fin),
#  ('esborrar', 'esborraré', 'VERB', VerbForm=Inf),
#  ('esborrar', 'esborrà', 'VERB', VerbForm=Inf),
#  ('esborrar', 'esborri', 'VERB', VerbForm=Inf),
#  ('esborrar', 'esborro', 'VERB', VerbForm=Inf),
#  ('esborrar',
#   'esborrarà',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Fut|VerbForm=Fin),
#  ('esborrar',
#   'esborraren',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Imp|VerbForm=Fin),
#  ('esborrar',
#   'esborrem',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=1|Tense=Fut|VerbForm=Fin),
#  ('esborrar', 'esborrant', 'VERB', VerbForm=Ger),
#  ('esborrar',
#   'esborrés',
#   'VERB',
#   Mood=Sub|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin),
#  ('etiqueta', 'etiqueta', 'NOUN', Gender=Fem|Number=Sing),
#  ('etiqueta', 'etiquetes', 'NOUN', Gender=Fem|Number=Plur),
#  ('etiquetar', 'etiquetar', 'VERB', VerbForm=Inf),
#  ('etiquetar',
#   'etiquetaran',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Fut|VerbForm=Fin),
#  ('etiquetar',
#   'etiquetessin',
#   'VERB',
#   Mood=Sub|Number=Plur|Person=3|Tense=Imp|VerbForm=Fin),
#  ('etiquetar',
#   'etiquetarà',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Fut|VerbForm=Fin),
#  ('etiquetar',
#   'etiquetava',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin),
#  ('etiquetar',
#   'etiquetarem',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=1|Tense=Fut|VerbForm=Fin),
#  ('etiquetar',
#   'etiqueti',
#   'VERB',
#   Mood=Sub|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin),
#  ('etiquetar', 'etiquetant', 'VERB', VerbForm=Ger),
#  ('etiquetar',
#   'etiquetaven',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Imp|VerbForm=Fin),
#  ('favorit', 'favoritos', 'NOUN', Gender=Masc|Number=Plur),
#  ('favorit', 'favorita', 'NOUN', Gender=Fem|Number=Sing),
#  ('favorit', 'favorits', 'NOUN', Gender=Masc|Number=Plur),
#  ('favorit', 'favorit', 'NOUN', Gender=Masc|Number=Sing),
#  ('fil', 'fils', 'NOUN', Gender=Masc|Number=Plur),
#  ('fil', 'fil', 'NOUN', Gender=Masc|Number=Sing),
#  ('guardar',
#   'guardarà',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Fut|VerbForm=Fin),
#  ('guardar',
#   'guardo',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin),
#  ('guardar',
#   'guardàvem',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=1|Tense=Imp|VerbForm=Fin),
#  ('guardar',
#   'guardava',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin),
#  ('guardar',
#   'guardam',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin),
#  ('guardar', 'guardant', 'VERB', VerbForm=Ger),
#  ('guardar',
#   'guarda',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin),
#  ('guardar',
#   'guardaven',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Imp|VerbForm=Fin),
#  ('guardar',
#   'guarde',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin),
#  ('guardar', 'guardaria', 'VERB', Mood=Cnd|Number=Sing|Person=3|VerbForm=Fin),
#  ('guardar',
#   'guardem',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin),
#  ('guardar',
#   'guardessin',
#   'VERB',
#   Mood=Sub|Number=Plur|Person=3|Tense=Imp|VerbForm=Fin),
#  ('guardar',
#   'guardaré',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin),
#  ('guardar', 'guardar', 'VERB', VerbForm=Inf),
#  ('guardar',
#   'guardeu',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin),
#  ('guardar',
#   'guardarem',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=1|Tense=Fut|VerbForm=Fin),
#  ('guardar',
#   'guardarien',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Imp|VerbForm=Fin),
#  ('guardar',
#   'guarden',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin),
#  ('guardar',
#   'guardareu',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Fut|VerbForm=Fin),
#  ('guardar',
#   'guardaren',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin),
#  ('guardar',
#   'guardaran',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Fut|VerbForm=Fin),
#  ('guardar',
#   'guardeu',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Fut|VerbForm=Fin),
#  ('guardar',
#   'guardeu',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin),
#  ('guardar',
#   'guardà',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin),
#  ('guardar',
#   'guardaràs',
#   'VERB',
#   Mood=Sub|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin),
#  ('guardar',
#   'guardés',
#   'VERB',
#   Mood=Sub|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin),
#  ('història', 'històries', 'NOUN', Gender=Fem|Number=Plur),
#  ('història', 'història', 'NOUN', Gender=Fem|Number=Sing),
#  ('menció', 'mencions', 'NOUN', Gender=Fem|Number=Plur),
#  ('menció', 'menció', 'NOUN', Gender=Fem|Number=Sing),
#  ('menció', 'menciones', 'NOUN', Gender=Fem|Number=Plur),
#  ('missatge', 'missatges', 'NOUN', Gender=Masc|Number=Plur),
#  ('missatge', 'missatge', 'NOUN', Gender=Masc|Number=Sing),
#  ('notificació', 'notificacions', 'NOUN', Gender=Fem|Number=Plur),
#  ('notificació', 'notificació', 'NOUN', Gender=Fem|Number=Sing),
#  ('notificació', 'notificaciones', 'NOUN', Gender=Fem|Number=Plur),
#  ('ocultar',
#   'ocultava',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin),
#  ('ocultar',
#   'ocultés',
#   'VERB',
#   Mood=Sub|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin),
#  ('ocultar',
#   'ocultaren',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin),
#  ('ocultar', 'ocultar', 'VERB', VerbForm=Inf),
#  ('ocultar', 'ocultant', 'VERB', VerbForm=Inf),
#  ('ocultar',
#   'oculten',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin),
#  ('ocultar',
#   'ocultarà',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Fut|VerbForm=Fin),
#  ('ocultar',
#   'ocultaran',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Fut|VerbForm=Fin),
#  ('ocultar',
#   'ocultem',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=1|Tense=Pres|VerbForm=Fin),
#  ('perfil', 'perfils', 'NOUN', Gender=Masc|Number=Plur),
#  ('perfil', 'perfil', 'NOUN', Gender=Masc|Number=Sing),
#  ('perfil', 'perfiles', 'NOUN', Gender=Masc|Number=Plur),
#  ('piulada', 'piulada', 'NOUN', Gender=Fem|Number=Sing),
#  ('piulada', 'piulades', 'NOUN', Gender=Fem|Number=Plur),
#  ('piular', 'piulant', 'VERB', VerbForm=Ger),
#  ('piular',
#   'piulem',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=1|Tense=Pres|VerbForm=Fin),
#  ('piular', 'piular', 'VERB', VerbForm=Inf),
#  ('piular',
#   'piulava',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin),
#  ('piular',
#   'piulaven',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Imp|VerbForm=Fin),
#  ('piular',
#   'piulen',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin),
#  ('piulet', 'piulet', 'NOUN', Gender=Masc|Number=Sing),
#  ('piulet', 'piulets', 'NOUN', Gender=Masc|Number=Plur),
#  ('preferit', 'preferits', 'NOUN', Gender=Masc|Number=Plur),
#  ('prohibir', 'prohibís', 'VERB', VerbForm=Inf),
#  ('prohibir',
#   'prohibirà',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Fut|VerbForm=Fin),
#  ('prohibir',
#   'prohibissin',
#   'VERB',
#   Mood=Sub|Number=Plur|Person=3|Tense=Imp|VerbForm=Fin),
#  ('prohibir',
#   'prohibeixi',
#   'VERB',
#   Mood=Sub|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin),
#  ('prohibir', 'prohibir', 'VERB', VerbForm=Inf),
#  ('prohibir',
#   'prohibim',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin),
#  ('prohibir',
#   'prohibiren',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin),
#  ('prohibir',
#   'prohibeixen',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin),
#  ('prohibir',
#   'prohibiran',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Fut|VerbForm=Fin),
#  ('prohibir',
#   'prohibien',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Imp|VerbForm=Fin),
#  ('prohibir',
#   'prohibeix',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin),
#  ('prohibir',
#   'prohibiria',
#   'VERB',
#   Mood=Cnd|Number=Sing|Person=3|VerbForm=Fin),
#  ('prohibir', 'prohibiu', 'VERB', VerbForm=Inf),
#  ('prohibir',
#   'prohibeixin',
#   'VERB',
#   Mood=Sub|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin),
#  ('prohibir',
#   'prohibia',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin),
#  ('prohibir',
#   'prohibix',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Fut|VerbForm=Fin),
#  ('prohibir',
#   'prohibeixo',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin),
#  ('prohibir',
#   'prohibirem',
#   'VERB',
#   Mood=Sub|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin),
#  ('prohibir',
#   'prohibeixes',
#   'VERB',
#   Mood=Sub|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin),
#  ('prohibir', 'prohibint', 'VERB', VerbForm=Ger),
#  ('prohibir',
#   'prohibirien',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Imp|VerbForm=Fin),
#  ('publicació', 'publicaciones', 'NOUN', Gender=Fem|Number=Plur),
#  ('publicació', 'publicació', 'NOUN', Gender=Fem|Number=Sing),
#  ('publicació', 'publicacions', 'NOUN', Gender=Fem|Number=Plur),
#  ('publicar',
#   'publica',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin),
#  ('publicar',
#   'publicaria',
#   'VERB',
#   Mood=Cnd|Number=Sing|Person=3|VerbForm=Fin),
#  ('publicar',
#   'publicaràs',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin),
#  ('publicar',
#   'publicam',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin),
#  ('publicar',
#   'publicarà',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Fut|VerbForm=Fin),
#  ('publicar',
#   'publicàvem',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Imp|VerbForm=Fin),
#  ('publicar',
#   'publicareu',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Fut|VerbForm=Fin),
#  ('publicar',
#   'publicau',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin),
#  ('publicar',
#   'publico',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin),
#  ('publicar',
#   'publicarem',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=1|Tense=Fut|VerbForm=Fin),
#  ('publicar',
#   'publicaren',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin),
#  ('publicar',
#   'publicàrem',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=1|Tense=Fut|VerbForm=Fin),
#  ('publicar',
#   'publicaven',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Imp|VerbForm=Fin),
#  ('publicar', 'publicant', 'VERB', VerbForm=Ger),
#  ('publicar',
#   'publicàs',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin),
#  ('publicar',
#   'publicarien',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Imp|VerbForm=Fin),
#  ('publicar',
#   'publicaríem',
#   'VERB',
#   Mood=Sub|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin),
#  ('publicar',
#   'publique',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin),
#  ('publicar',
#   'publicaré',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Fut|VerbForm=Fin),
#  ('publicar',
#   'publicaran',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Fut|VerbForm=Fin),
#  ('publicar',
#   'publicava',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin),
#  ('publicar', 'publicar', 'VERB', VerbForm=Inf),
#  ('reenviar',
#   'reenviarem',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=1|Tense=Fut|VerbForm=Fin),
#  ('reenviar',
#   'reenvia',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin),
#  ('reenviar',
#   'reenvien',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Imp|VerbForm=Fin),
#  ('reenviar',
#   'reenvieu',
#   'VERB',
#   Mood=Sub|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin),
#  ('reenviar', 'reenviar', 'VERB', VerbForm=Inf),
#  ('reenviar',
#   'reenvio',
#   'VERB',
#   Mood=Sub|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin),
#  ('reenviar', 'reenviant', 'VERB', VerbForm=Ger),
#  ('reenviar',
#   'reenviem',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=1|Tense=Pres|VerbForm=Fin),
#  ('repiulada', 'repiulada', 'NOUN', Gender=Fem|Number=Sing),
#  ('repiular',
#   'repiulen',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin),
#  ('repiular', 'repiulant', 'VERB', VerbForm=Ger),
#  ('repiular', 'repiular', 'VERB', VerbForm=Inf),
#  ('repiulet', 'repiulets', 'NOUN', Gender=Masc|Number=Plur),
#  ('respondre',
#   'respon',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin),
#  ('respondre', 'respondré', 'VERB', VerbForm=Inf),
#  ('respondre',
#   'responc',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin),
#  ('respondre',
#   'respondrem',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=1|Tense=Fut|VerbForm=Fin),
#  ('respondre',
#   'respondreu',
#   'VERB',
#   Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part),
#  ('respondre',
#   'respondrien',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Imp|VerbForm=Fin),
#  ('respondre',
#   'respondríem',
#   'VERB',
#   Mood=Cnd|Number=Plur|Person=1|VerbForm=Fin),
#  ('respondre',
#   'respondrà',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Fut|VerbForm=Fin),
#  ('respondre',
#   'respondria',
#   'VERB',
#   Mood=Cnd|Number=Sing|Person=3|VerbForm=Fin),
#  ('respondre',
#   'respondràs',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin),
#  ('respondre', 'respondre', 'VERB', VerbForm=Inf),
#  ('respondre',
#   'respondran',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Fut|VerbForm=Fin),
#  ('resposta', 'respostes', 'NOUN', Gender=Fem|Number=Plur),
#  ('resposta', 'resposta', 'NOUN', Gender=Fem|Number=Sing),
#  ('restringir',
#   'restringien',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Imp|VerbForm=Fin),
#  ('restringir',
#   'restringiria',
#   'VERB',
#   Mood=Cnd|Number=Sing|Person=3|VerbForm=Fin),
#  ('restringir',
#   'restringeixi',
#   'VERB',
#   Mood=Sub|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin),
#  ('restringir', 'restringir', 'VERB', VerbForm=Inf),
#  ('restringir',
#   'restringeixen',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin),
#  ('restringir', 'restringint', 'VERB', VerbForm=Ger),
#  ('restringir',
#   'restringeix',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin),
#  ('restringir',
#   'restringirà',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Fut|VerbForm=Fin),
#  ('restringir',
#   'restringissin',
#   'VERB',
#   Mood=Sub|Number=Plur|Person=3|Tense=Imp|VerbForm=Fin),
#  ('restringir',
#   'restringia',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin),
#  ('restringir',
#   'restringeixin',
#   'VERB',
#   Mood=Sub|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin),
#  ('restringir',
#   'restringís',
#   'VERB',
#   Mood=Sub|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin),
#  ('restringir',
#   'restringiran',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Fut|VerbForm=Fin),
#  ('retuit', 'retuits', 'NOUN', Gender=Masc|Number=Plur),
#  ('retuit', 'retuit', 'NOUN', Gender=Masc|Number=Sing),
#  ('retuitar', 'retuitar', 'VERB', VerbForm=Inf),
#  ('retuitejar',
#   'retuiteja',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin),
#  ('retuitejar', 'retuitejant', 'VERB', VerbForm=Ger),
#  ('retuitejar', 'retuitejar', 'VERB', VerbForm=Inf),
#  ('seguidor', 'seguidor', 'NOUN', Gender=Masc|Number=Sing),
#  ('seguidor', 'seguidora', 'NOUN', Gender=Masc|Number=Sing),
#  ('seguidor', 'seguidors', 'NOUN', Gender=Masc|Number=Plur),
#  ('seguir', 'seguint', 'VERB', VerbForm=Ger),
#  ('seguir',
#   'segueixis',
#   'VERB',
#   Mood=Sub|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin),
#  ('seguir',
#   'seguesc',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin),
#  ('seguir',
#   'seguissin',
#   'VERB',
#   Mood=Sub|Number=Plur|Person=3|Tense=Imp|VerbForm=Fin),
#  ('seguir', 'seguiu', 'VERB', Mood=Imp|Number=Plur|Person=1|VerbForm=Fin),
#  ('seguir',
#   'segueixin',
#   'VERB',
#   Mood=Sub|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin),
#  ('seguir', 'seguíem', 'VERB', Mood=Cnd|Number=Plur|Person=1|VerbForm=Fin),
#  ('seguir',
#   'seguien',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Imp|VerbForm=Fin),
#  ('seguir',
#   'seguirem',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=1|Tense=Fut|VerbForm=Fin),
#  ('seguir',
#   'seguixo',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin),
#  ('seguir', 'seguiria', 'VERB', Mood=Cnd|Number=Sing|Person=3|VerbForm=Fin),
#  ('seguir',
#   'segueixi',
#   'VERB',
#   Mood=Sub|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin),
#  ('seguir', 'seguissis', 'VERB', VerbForm=Inf),
#  ('seguir', 'seguiríem', 'VERB', Mood=Cnd|Number=Plur|Person=1|VerbForm=Fin),
#  ('seguir',
#   'seguíssiu',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin),
#  ('seguir',
#   'seguiren',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin),
#  ('seguir',
#   'seguís',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin),
#  ('seguir', 'seguim', 'VERB', Mood=Imp|Number=Plur|Person=1|VerbForm=Fin),
#  ('seguir',
#   'seguíeu',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=1|Tense=Pres|VerbForm=Fin),
#  ('seguir',
#   'segueixen',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin),
#  ('seguir',
#   'seguírem',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=1|Tense=Fut|VerbForm=Fin),
#  ('seguir', 'seguiríeu', 'VERB', Mood=Imp|Number=Plur|Person=1|VerbForm=Fin),
#  ('seguir', 'seguiràs', 'VERB', Mood=Imp|Number=Plur|Person=1|VerbForm=Fin),
#  ('seguir',
#   'seguíssim',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin),
#  ('seguir',
#   'segueix',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin),
#  ('seguir',
#   'seguia',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin),
#  ('seguir', 'seguiu', 'VERB', VerbForm=Inf),
#  ('seguir',
#   'segueixo',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin),
#  ('seguir',
#   'seguisc',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin),
#  ('seguir',
#   'seguissen',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin),
#  ('seguir',
#   'seguiran',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Fut|VerbForm=Fin),
#  ('seguir',
#   'seguiu',
#   'VERB',
#   Mood=Sub|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin),
#  ('seguir', 'seguir', 'VERB', VerbForm=Inf),
#  ('seguir',
#   'seguiré',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=1|Tense=Fut|VerbForm=Fin),
#  ('seguir',
#   'seguirien',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Imp|VerbForm=Fin),
#  ('seguir',
#   'seguirà',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Fut|VerbForm=Fin),
#  ('seguir',
#   'seguix',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin),
#  ('seguir', 'seguireu', 'VERB', Mood=Imp|Number=Plur|Person=1|VerbForm=Fin),
#  ('silenciar',
#   'silenciava',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin),
#  ('silenciar',
#   'silenciïn',
#   'VERB',
#   Mood=Sub|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin),
#  ('silenciar',
#   'silenciaran',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Fut|VerbForm=Fin),
#  ('silenciar',
#   'silenciem',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=1|Tense=Pres|VerbForm=Fin),
#  ('silenciar', 'silenciar', 'VERB', VerbForm=Inf),
#  ('silenciar',
#   'silenciaven',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Imp|VerbForm=Fin),
#  ('silenciar',
#   'silenciarà',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Fut|VerbForm=Fin),
#  ('silenciar', 'silenciant', 'VERB', VerbForm=Ger),
#  ('silenciar',
#   'silencien',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Imp|VerbForm=Fin),
#  ('subscriure',
#   'subscriuria',
#   'VERB',
#   Mood=Cnd|Number=Sing|Person=3|VerbForm=Fin),
#  ('subscriure', 'subscriure', 'VERB', VerbForm=Inf),
#  ('subscriure',
#   'subscriurem',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=1|Tense=Fut|VerbForm=Fin),
#  ('subscriure',
#   'subscriurien',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Imp|VerbForm=Fin),
#  ('subscriure',
#   'subscriuran',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Fut|VerbForm=Fin),
#  ('subscriure',
#   'subscriurà',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Fut|VerbForm=Fin),
#  ('tuit', 'tuits', 'NOUN', Gender=Masc|Number=Plur),
#  ('tuit', 'tuit', 'NOUN', Gender=Masc|Number=Sing),
#  ('tuitar', 'tuitar', 'VERB', VerbForm=Inf),
#  ('tuitejar', 'tuitejar', 'VERB', VerbForm=Inf),
#  ('tuitejar', 'tuitejant', 'VERB', VerbForm=Ger),
#  ('tuitejar',
#   'tuiteja',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin)]

# %%
len(infl_list)
# Out:
# 491

# %%
infl_list[100]
# Out:
# ('comentari', 'comentari', 'NOUN', Gender=Masc|Number=Sing)

# %%
# Remove duplicate tuples
m = list(set(infl_list))
len(m)
# Out:
# 457

# %%
m
# Out:
# [('respondre', 'respondré', 'VERB', VerbForm=Inf),
#  ('blocar',
#   'blocava',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin),
#  ('silenciar',
#   'silenciïn',
#   'VERB',
#   Mood=Sub|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin),
#  ('restringir',
#   'restringeixen',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin),
#  ('publicar',
#   'publicaria',
#   'VERB',
#   Mood=Cnd|Number=Sing|Person=3|VerbForm=Fin),
#  ('denunciar', 'denunciar', 'VERB', VerbForm=Inf),
#  ('arxivar', 'arxivar', 'VERB', VerbForm=Inf),
#  ('denunciar', 'denunciant', 'VERB', VerbForm=Ger),
#  ('seguir',
#   'seguirem',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=1|Tense=Fut|VerbForm=Fin),
#  ('compartir',
#   'comparteixo',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin),
#  ('publicar',
#   'publico',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin),
#  ('silenciar',
#   'silenciem',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=1|Tense=Pres|VerbForm=Fin),
#  ('resposta', 'resposta', 'NOUN', Gender=Fem|Number=Sing),
#  ('esborrar',
#   'esborressin',
#   'VERB',
#   Mood=Sub|Number=Plur|Person=3|Tense=Imp|VerbForm=Fin),
#  ('prohibir',
#   'prohibiran',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Fut|VerbForm=Fin),
#  ('esborrar',
#   'esborraria',
#   'VERB',
#   Mood=Cnd|Number=Sing|Person=3|VerbForm=Fin),
#  ('compartir',
#   'comparteixi',
#   'VERB',
#   Mood=Sub|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin),
#  ('compartir',
#   'compartíssim',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=1|Tense=Pres|VerbForm=Fin),
#  ('enviar', 'envieu', 'VERB', VerbForm=Ger),
#  ('comentar', 'comentessis', 'VERB', VerbForm=Inf),
#  ('comentar',
#   'comentàrem',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=1|Tense=Fut|VerbForm=Fin),
#  ('enviar', 'enviant', 'VERB', VerbForm=Ger),
#  ('publicar',
#   'publicàrem',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=1|Tense=Fut|VerbForm=Fin),
#  ('seguir', 'seguiràs', 'VERB', Mood=Imp|Number=Plur|Person=1|VerbForm=Fin),
#  ('subscriure',
#   'subscriuria',
#   'VERB',
#   Mood=Cnd|Number=Sing|Person=3|VerbForm=Fin),
#  ('cronologia', 'cronologies', 'NOUN', Gender=Fem|Number=Plur),
#  ('seguir',
#   'seguiu',
#   'VERB',
#   Mood=Sub|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin),
#  ('enviar',
#   'envieu',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=1|Tense=Pres|VerbForm=Fin),
#  ('ocultar', 'ocultant', 'VERB', VerbForm=Inf),
#  ('reenviar',
#   'reenvieu',
#   'VERB',
#   Mood=Sub|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin),
#  ('denunciar',
#   'denunciï',
#   'VERB',
#   Mood=Sub|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin),
#  ('seguir', 'seguint', 'VERB', VerbForm=Ger),
#  ('seguir',
#   'segueixis',
#   'VERB',
#   Mood=Sub|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin),
#  ('bloquejar',
#   'bloquejaran',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Fut|VerbForm=Fin),
#  ('compartir', 'compartint', 'VERB', VerbForm=Ger),
#  ('publicar',
#   'publicam',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin),
#  ('esborrar',
#   'esborrarem',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=1|Tense=Fut|VerbForm=Fin),
#  ('amagar',
#   'amagarien',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Imp|VerbForm=Fin),
#  ('amagar',
#   'amagarà',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Fut|VerbForm=Fin),
#  ('comentar',
#   'comentam',
#   'VERB',
#   Mood=Sub|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin),
#  ('arxivar',
#   'arxivessin',
#   'VERB',
#   Mood=Sub|Number=Plur|Person=3|Tense=Imp|VerbForm=Fin),
#  ('amagar',
#   'amaga',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin),
#  ('comentari', 'comentari', 'NOUN', Gender=Masc|Number=Sing),
#  ('enviar',
#   'enviaríem',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=1|Tense=Imp|VerbForm=Fin),
#  ('publicar',
#   'publicarem',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=1|Tense=Fut|VerbForm=Fin),
#  ('esborrar', 'esborrar', 'VERB', VerbForm=Inf),
#  ('piular',
#   'piulaven',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Imp|VerbForm=Fin),
#  ('compartir', 'compartir', 'VERB', VerbForm=Inf),
#  ('clavar',
#   'clavaré',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin),
#  ('prohibir',
#   'prohibeixen',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin),
#  ('seguir',
#   'seguírem',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=1|Tense=Fut|VerbForm=Fin),
#  ('clavar',
#   'clavem',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=1|Tense=Imp|VerbForm=Fin),
#  ('prohibir',
#   'prohibiria',
#   'VERB',
#   Mood=Cnd|Number=Sing|Person=3|VerbForm=Fin),
#  ('repiulada', 'repiulada', 'NOUN', Gender=Fem|Number=Sing),
#  ('favorit', 'favoritos', 'NOUN', Gender=Masc|Number=Plur),
#  ('seguir',
#   'seguíssim',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin),
#  ('compartir',
#   'compartíem',
#   'VERB',
#   Mood=Cnd|Number=Plur|Person=1|VerbForm=Fin),
#  ('perfil', 'perfil', 'NOUN', Gender=Masc|Number=Sing),
#  ('enviar',
#   'enviaran',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Fut|VerbForm=Fin),
#  ('publicar',
#   'publicarien',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Imp|VerbForm=Fin),
#  ('esborrar',
#   'esborraren',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Imp|VerbForm=Fin),
#  ('comentar', 'comentà', 'VERB', Mood=Cnd|Number=Sing|Person=1|VerbForm=Fin),
#  ('guardar',
#   'guardeu',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Fut|VerbForm=Fin),
#  ('guardar',
#   'guardà',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin),
#  ('restringir',
#   'restringiran',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Fut|VerbForm=Fin),
#  ('amagar',
#   'amagaré',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=1|Tense=Fut|VerbForm=Fin),
#  ('compartir',
#   'comparteixen',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin),
#  ('clavar',
#   'clavaran',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Fut|VerbForm=Fin),
#  ('enviar', 'envie', 'VERB', VerbForm=Inf),
#  ('compartir',
#   'compartirien',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin),
#  ('denunciar',
#   'denuncien',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin),
#  ('denunciar',
#   'denunciaré',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Fut|VerbForm=Fin),
#  ('respondre',
#   'respondran',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Fut|VerbForm=Fin),
#  ('enviar',
#   'envii',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin),
#  ('restringir', 'restringir', 'VERB', VerbForm=Inf),
#  ('amagar', 'amagant', 'VERB', VerbForm=Ger),
#  ('repiular', 'repiular', 'VERB', VerbForm=Inf),
#  ('compartir',
#   'compartirà',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Fut|VerbForm=Fin),
#  ('seguir', 'seguim', 'VERB', Mood=Imp|Number=Plur|Person=1|VerbForm=Fin),
#  ('retuitejar', 'retuitejant', 'VERB', VerbForm=Ger),
#  ('seguir',
#   'segueixen',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin),
#  ('comentar',
#   'comentàvem',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=1|Tense=Imp|VerbForm=Fin),
#  ('amagar',
#   'amagàvem',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=1|Tense=Imp|VerbForm=Fin),
#  ('denunciar',
#   'denunciaria',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin),
#  ('prohibir', 'prohibiu', 'VERB', VerbForm=Inf),
#  ('esborrar', 'esborrà', 'VERB', VerbForm=Inf),
#  ('seguir', 'seguiríeu', 'VERB', Mood=Imp|Number=Plur|Person=1|VerbForm=Fin),
#  ('denunciar',
#   'denunciaren',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin),
#  ('piulada', 'piulades', 'NOUN', Gender=Fem|Number=Plur),
#  ('seguir',
#   'segueixo',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin),
#  ('missatge', 'missatges', 'NOUN', Gender=Masc|Number=Plur),
#  ('compte', 'comptes', 'NOUN', Gender=Masc|Number=Plur),
#  ('etiquetar',
#   'etiquetarà',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Fut|VerbForm=Fin),
#  ('enviar',
#   'enviàrem',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=1|Tense=Fut|VerbForm=Fin),
#  ('arxivar',
#   'arxivarà',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Fut|VerbForm=Fin),
#  ('seguidor', 'seguidor', 'NOUN', Gender=Masc|Number=Sing),
#  ('publicar',
#   'publicaran',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Fut|VerbForm=Fin),
#  ('etiquetar',
#   'etiquetarem',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=1|Tense=Fut|VerbForm=Fin),
#  ('enviar',
#   'enviarien',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Imp|VerbForm=Fin),
#  ('compartir',
#   'comparteixes',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=2|Tense=Pres|VerbForm=Fin),
#  ('esborrar',
#   'esborrés',
#   'VERB',
#   Mood=Sub|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin),
#  ('amagar',
#   'amagaren',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin),
#  ('enviar',
#   'enviaven',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Imp|VerbForm=Fin),
#  ('tuit', 'tuits', 'NOUN', Gender=Masc|Number=Plur),
#  ('publicació', 'publicació', 'NOUN', Gender=Fem|Number=Sing),
#  ('amagar',
#   'amagaran',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Fut|VerbForm=Fin),
#  ('prohibir',
#   'prohibim',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin),
#  ('compartir',
#   'compartin',
#   'VERB',
#   Mood=Sub|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin),
#  ('subscriure',
#   'subscriurem',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=1|Tense=Fut|VerbForm=Fin),
#  ('piular',
#   'piulava',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin),
#  ('comentar',
#   'comenten',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin),
#  ('compartir',
#   'compartiu',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=1|Tense=Imp|VerbForm=Fin),
#  ('comentar',
#   'comentarà',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Fut|VerbForm=Fin),
#  ('comentari', 'comentaris', 'NOUN', Gender=Masc|Number=Plur),
#  ('compartir',
#   'compartissin',
#   'VERB',
#   Mood=Sub|Number=Plur|Person=3|Tense=Imp|VerbForm=Fin),
#  ('tuitejar', 'tuitejar', 'VERB', VerbForm=Inf),
#  ('amagar',
#   'amagam',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin),
#  ('etiquetar',
#   'etiquetava',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin),
#  ('seguidor', 'seguidors', 'NOUN', Gender=Masc|Number=Plur),
#  ('restringir',
#   'restringís',
#   'VERB',
#   Mood=Sub|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin),
#  ('etiquetar',
#   'etiqueti',
#   'VERB',
#   Mood=Sub|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin),
#  ('denunciar',
#   'denunciessin',
#   'VERB',
#   Mood=Sub|Number=Plur|Person=3|Tense=Imp|VerbForm=Fin),
#  ('comentar',
#   'comento',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin),
#  ('compartir',
#   'compartiria',
#   'VERB',
#   Mood=Cnd|Number=Sing|Person=3|VerbForm=Fin),
#  ('publicar',
#   'publicàs',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin),
#  ('favorit', 'favorita', 'NOUN', Gender=Fem|Number=Sing),
#  ('enviar',
#   'enviï',
#   'VERB',
#   Mood=Sub|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin),
#  ('esborrar', 'esborrant', 'VERB', VerbForm=Ger),
#  ('etiquetar',
#   'etiquetaven',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Imp|VerbForm=Fin),
#  ('arxivar',
#   'arxiven',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Imp|VerbForm=Fin),
#  ('denunciar',
#   'denunciïn',
#   'VERB',
#   Mood=Sub|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin),
#  ('blocar',
#   'bloca',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin),
#  ('perfil', 'perfils', 'NOUN', Gender=Masc|Number=Plur),
#  ('denunciar', 'denuncià', 'VERB', VerbForm=Inf),
#  ('seguir', 'seguiria', 'VERB', Mood=Cnd|Number=Sing|Person=3|VerbForm=Fin),
#  ('retuit', 'retuits', 'NOUN', Gender=Masc|Number=Plur),
#  ('respondre',
#   'respondrem',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=1|Tense=Fut|VerbForm=Fin),
#  ('denunciar',
#   'denunciàrem',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Fut|VerbForm=Fin),
#  ('respondre',
#   'responc',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin),
#  ('comentar',
#   'comentarem',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=1|Tense=Fut|VerbForm=Fin),
#  ('prohibir',
#   'prohibeixin',
#   'VERB',
#   Mood=Sub|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin),
#  ('enviar',
#   'envieu',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin),
#  ('compte', 'compte', 'NOUN', Gender=Masc|Number=Sing),
#  ('guardar',
#   'guardareu',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Fut|VerbForm=Fin),
#  ('publicació', 'publicaciones', 'NOUN', Gender=Fem|Number=Plur),
#  ('esborrar', 'esborro', 'VERB', VerbForm=Inf),
#  ('publicar',
#   'publicaven',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Imp|VerbForm=Fin),
#  ('amic', 'amigues', 'NOUN', Gender=Fem|Number=Plur),
#  ('guardar',
#   'guardaran',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Fut|VerbForm=Fin),
#  ('bloquejar',
#   'bloquejaria',
#   'VERB',
#   Mood=Cnd|Number=Sing|Person=3|VerbForm=Fin),
#  ('seguir',
#   'seguix',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin),
#  ('enviar',
#   'envia',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin),
#  ('enviar',
#   'envien',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin),
#  ('publicar',
#   'publicava',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin),
#  ('denunciar',
#   'denunciàvem',
#   'VERB',
#   Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part),
#  ('etiquetar', 'etiquetant', 'VERB', VerbForm=Ger),
#  ('denunciar',
#   'denuncio',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin),
#  ('notificació', 'notificaciones', 'NOUN', Gender=Fem|Number=Plur),
#  ('esborrar',
#   'esborren',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin),
#  ('enviar',
#   'envií',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Fut|VerbForm=Fin),
#  ('reenviar',
#   'reenvien',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Imp|VerbForm=Fin),
#  ('guardar',
#   'guardam',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin),
#  ('seguir', 'seguiu', 'VERB', Mood=Imp|Number=Plur|Person=1|VerbForm=Fin),
#  ('comentar',
#   'comentaran',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Fut|VerbForm=Fin),
#  ('seguir',
#   'seguien',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Imp|VerbForm=Fin),
#  ('denunciar',
#   'denuncieu',
#   'VERB',
#   Mood=Sub|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin),
#  ('piular', 'piular', 'VERB', VerbForm=Inf),
#  ('seguir',
#   'seguiren',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin),
#  ('guardar', 'guardaria', 'VERB', Mood=Cnd|Number=Sing|Person=3|VerbForm=Fin),
#  ('respondre',
#   'respondríem',
#   'VERB',
#   Mood=Cnd|Number=Plur|Person=1|VerbForm=Fin),
#  ('bloquejar',
#   'bloqueja',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin),
#  ('tuitar', 'tuitar', 'VERB', VerbForm=Inf),
#  ('etiquetar',
#   'etiquetaran',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Fut|VerbForm=Fin),
#  ('denunciar',
#   'denuncii',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin),
#  ('bloquejar',
#   'bloquejava',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin),
#  ('respondre',
#   'respondrien',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Imp|VerbForm=Fin),
#  ('restringir',
#   'restringirà',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Fut|VerbForm=Fin),
#  ('denunciar',
#   'denunciada',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin),
#  ('silenciar',
#   'silenciarà',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Fut|VerbForm=Fin),
#  ('canal', 'canals', 'NOUN', Gender=Masc|Number=Plur),
#  ('silenciar',
#   'silencien',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Imp|VerbForm=Fin),
#  ('enviar',
#   'enviàvem',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=1|Tense=Pres|VerbForm=Fin),
#  ('amagar',
#   'amague',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin),
#  ('seguidor', 'seguidora', 'NOUN', Gender=Masc|Number=Sing),
#  ('comentar',
#   'comenta',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin),
#  ('amagar',
#   'amago',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin),
#  ('menció', 'menció', 'NOUN', Gender=Fem|Number=Sing),
#  ('comentar',
#   'comenteu',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin),
#  ('favorit', 'favorit', 'NOUN', Gender=Masc|Number=Sing),
#  ('arxivar',
#   'arxivaven',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Imp|VerbForm=Fin),
#  ('bloquejar',
#   'bloquejat',
#   'VERB',
#   Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part),
#  ('enviar',
#   'enviaré',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=1|Tense=Fut|VerbForm=Fin),
#  ('comentar', 'comentar', 'VERB', VerbForm=Inf),
#  ('seguir',
#   'segueixi',
#   'VERB',
#   Mood=Sub|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin),
#  ('enviar',
#   'enviarà',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Fut|VerbForm=Fin),
#  ('enviar',
#   'enviïs',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=1|Tense=Fut|VerbForm=Fin),
#  ('resposta', 'respostes', 'NOUN', Gender=Fem|Number=Plur),
#  ('retuitejar',
#   'retuiteja',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin),
#  ('bloquejar',
#   'bloquejaven',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Imp|VerbForm=Fin),
#  ('seguir',
#   'segueix',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin),
#  ('comentar',
#   'comentaré',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=1|Tense=Fut|VerbForm=Fin),
#  ('etiquetar',
#   'etiquetessin',
#   'VERB',
#   Mood=Sub|Number=Plur|Person=3|Tense=Imp|VerbForm=Fin),
#  ('seguir',
#   'seguissen',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin),
#  ('amagar',
#   'amagà',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin),
#  ('preferit', 'preferits', 'NOUN', Gender=Masc|Number=Plur),
#  ('compartir',
#   'compartirem',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=1|Tense=Fut|VerbForm=Fin),
#  ('clavar',
#   'clavaren',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin),
#  ('fil', 'fils', 'NOUN', Gender=Masc|Number=Plur),
#  ('compartir',
#   'compartírem',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=1|Tense=Fut|VerbForm=Fin),
#  ('guardar',
#   'guardo',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin),
#  ('ocultar', 'ocultar', 'VERB', VerbForm=Inf),
#  ('seguir',
#   'seguesc',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin),
#  ('història', 'història', 'NOUN', Gender=Fem|Number=Sing),
#  ('publicar',
#   'publicaràs',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin),
#  ('enviar',
#   'envio',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Fut|VerbForm=Fin),
#  ('subscriure',
#   'subscriurà',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Fut|VerbForm=Fin),
#  ('reenviar',
#   'reenviarem',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=1|Tense=Fut|VerbForm=Fin),
#  ('publicar',
#   'publicareu',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Fut|VerbForm=Fin),
#  ('enviar',
#   'enviava',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin),
#  ('guardar',
#   'guardaven',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Imp|VerbForm=Fin),
#  ('denunciar',
#   'denuncia',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin),
#  ('reenviar', 'reenviant', 'VERB', VerbForm=Ger),
#  ('guardar', 'guardar', 'VERB', VerbForm=Inf),
#  ('prohibir',
#   'prohibien',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Imp|VerbForm=Fin),
#  ('arxivar',
#   'arxivaran',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Fut|VerbForm=Fin),
#  ('restringir',
#   'restringiria',
#   'VERB',
#   Mood=Cnd|Number=Sing|Person=3|VerbForm=Fin),
#  ('prohibir',
#   'prohibirem',
#   'VERB',
#   Mood=Sub|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin),
#  ('comentar',
#   'comentessin',
#   'VERB',
#   Mood=Sub|Number=Plur|Person=3|Tense=Imp|VerbForm=Fin),
#  ('publicar',
#   'publique',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin),
#  ('amagar', 'amagar', 'VERB', VerbForm=Inf),
#  ('bloquejar',
#   'bloquejarien',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Imp|VerbForm=Fin),
#  ('tuit', 'tuit', 'NOUN', Gender=Masc|Number=Sing),
#  ('guardar',
#   'guardarà',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Fut|VerbForm=Fin),
#  ('enviar',
#   'enviam',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Fut|VerbForm=Fin),
#  ('esborrar', 'esborris', 'VERB', VerbForm=Inf),
#  ('esborrar',
#   'esborraran',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Fut|VerbForm=Fin),
#  ('prohibir',
#   'prohibeixi',
#   'VERB',
#   Mood=Sub|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin),
#  ('amagar',
#   'amagava',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin),
#  ('denunciar',
#   'denunciava',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin),
#  ('tuitejar',
#   'tuiteja',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin),
#  ('bloquejar',
#   'bloquejarem',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=1|Tense=Fut|VerbForm=Fin),
#  ('bloquejar',
#   'bloquejaren',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin),
#  ('compartir',
#   'compartiran',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Fut|VerbForm=Fin),
#  ('prohibir',
#   'prohibiren',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin),
#  ('seguir', 'seguiríem', 'VERB', Mood=Cnd|Number=Plur|Person=1|VerbForm=Fin),
#  ('amic', 'amiga', 'NOUN', Gender=Fem|Number=Sing),
#  ('comentar',
#   'comentaràs',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=1|Tense=Pres|VerbForm=Fin),
#  ('compartir',
#   'compartiré',
#   'VERB',
#   Mood=Sub|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin),
#  ('guardar',
#   'guardem',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin),
#  ('esborrar',
#   'esborrava',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin),
#  ('respondre',
#   'respondrà',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Fut|VerbForm=Fin),
#  ('compartir',
#   'compartiràs',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=1|Tense=Pres|VerbForm=Fin),
#  ('guardar',
#   'guardarem',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=1|Tense=Fut|VerbForm=Fin),
#  ('publicació', 'publicacions', 'NOUN', Gender=Fem|Number=Plur),
#  ('enviar',
#   'enviaràs',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin),
#  ('subscriure',
#   'subscriurien',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Imp|VerbForm=Fin),
#  ('respondre', 'respondre', 'VERB', VerbForm=Inf),
#  ('amagar',
#   'amag',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin),
#  ('amic', 'amic', 'NOUN', Gender=Masc|Number=Sing),
#  ('compartir', 'compartireu', 'VERB', VerbForm=Ger),
#  ('tuitejar', 'tuitejant', 'VERB', VerbForm=Ger),
#  ('seguir',
#   'seguirien',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Imp|VerbForm=Fin),
#  ('amagar',
#   'amagen',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin),
#  ('història', 'històries', 'NOUN', Gender=Fem|Number=Plur),
#  ('publicar',
#   'publicaré',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Fut|VerbForm=Fin),
#  ('prohibir',
#   'prohibeixes',
#   'VERB',
#   Mood=Sub|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin),
#  ('compartir',
#   'compartiu',
#   'VERB',
#   Mood=Cnd|Number=Plur|Person=1|VerbForm=Fin),
#  ('ocultar',
#   'ocultava',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin),
#  ('publicar',
#   'publica',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin),
#  ('piulet', 'piulets', 'NOUN', Gender=Masc|Number=Plur),
#  ('enviar',
#   'enviau',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Fut|VerbForm=Fin),
#  ('compartir',
#   'compartissis',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin),
#  ('silenciar', 'silenciar', 'VERB', VerbForm=Inf),
#  ('publicar',
#   'publicàvem',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Imp|VerbForm=Fin),
#  ('compartir',
#   'compartiren',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin),
#  ('ocultar',
#   'ocultem',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=1|Tense=Pres|VerbForm=Fin),
#  ('prohibir', 'prohibir', 'VERB', VerbForm=Inf),
#  ('esborrar',
#   'esborra',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin),
#  ('cronologia', 'cronologia', 'NOUN', Gender=Fem|Number=Sing),
#  ('amic', 'amics', 'NOUN', Gender=Masc|Number=Plur),
#  ('enviar',
#   'enviarem',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=1|Tense=Fut|VerbForm=Fin),
#  ('arxivar',
#   'arxivava',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin),
#  ('guardar',
#   'guardaré',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin),
#  ('compartir',
#   'compartisc',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin),
#  ('clavar',
#   'clavessin',
#   'VERB',
#   Mood=Sub|Number=Plur|Person=3|Tense=Imp|VerbForm=Fin),
#  ('esborrar', 'esborraré', 'VERB', VerbForm=Inf),
#  ('enviar', 'enviaria', 'VERB', Mood=Cnd|Number=Sing|Person=3|VerbForm=Fin),
#  ('seguir',
#   'seguisc',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin),
#  ('amagar',
#   'amagaven',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Imp|VerbForm=Fin),
#  ('arxivar', 'arxivant', 'VERB', VerbForm=Ger),
#  ('seguir',
#   'seguirà',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Fut|VerbForm=Fin),
#  ('guardar',
#   'guardeu',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin),
#  ('compartir',
#   'comparteixin',
#   'VERB',
#   Mood=Sub|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin),
#  ('clavar',
#   'clavava',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin),
#  ('clavar', 'clavà', 'VERB', VerbForm=Inf),
#  ('compartir',
#   'compartís',
#   'VERB',
#   Mood=Sub|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin),
#  ('silenciar',
#   'silenciava',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin),
#  ('comentar',
#   'comentaves',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin),
#  ('enviar',
#   'enviéssim',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin),
#  ('clavar', 'clavant', 'VERB', VerbForm=Ger),
#  ('restringir',
#   'restringeix',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin),
#  ('comentar', 'comentant', 'VERB', VerbForm=Ger),
#  ('etiqueta', 'etiqueta', 'NOUN', Gender=Fem|Number=Sing),
#  ('denunciar',
#   'denuncie',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin),
#  ('enviar',
#   'enviessis',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin),
#  ('menció', 'mencions', 'NOUN', Gender=Fem|Number=Plur),
#  ('seguir',
#   'seguixo',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin),
#  ('guardar',
#   'guarda',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin),
#  ('denunciar',
#   'denunciïs',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin),
#  ('guardar',
#   'guarde',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin),
#  ('enviar',
#   'enviaren',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin),
#  ('blocar', 'blocant', 'VERB', VerbForm=Ger),
#  ('restringir',
#   'restringissin',
#   'VERB',
#   Mood=Sub|Number=Plur|Person=3|Tense=Imp|VerbForm=Fin),
#  ('subscriure',
#   'subscriuran',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Fut|VerbForm=Fin),
#  ('retuit', 'retuit', 'NOUN', Gender=Masc|Number=Sing),
#  ('compartir',
#   'comparteix',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin),
#  ('seguir', 'seguiu', 'VERB', VerbForm=Inf),
#  ('denunciar',
#   'denunciaran',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Fut|VerbForm=Fin),
#  ('denunciar',
#   'denunciaven',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Imp|VerbForm=Fin),
#  ('enviar',
#   'enviareu',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin),
#  ('comentar',
#   'comentes',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin),
#  ('comentar',
#   'comentem',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=1|Tense=Pres|VerbForm=Fin),
#  ('perfil', 'perfiles', 'NOUN', Gender=Masc|Number=Plur),
#  ('reenviar',
#   'reenviem',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=1|Tense=Pres|VerbForm=Fin),
#  ('subscriure', 'subscriure', 'VERB', VerbForm=Inf),
#  ('seguir', 'seguissis', 'VERB', VerbForm=Inf),
#  ('enviar', 'enviar', 'VERB', VerbForm=Inf),
#  ('comentar',
#   'comenti',
#   'VERB',
#   Mood=Sub|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin),
#  ('publicar',
#   'publicaren',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin),
#  ('notificació', 'notificacions', 'NOUN', Gender=Fem|Number=Plur),
#  ('denunciar',
#   'denunciem',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=1|Tense=Pres|VerbForm=Fin),
#  ('esborrar', 'esborri', 'VERB', VerbForm=Inf),
#  ('enviar',
#   'enviis',
#   'VERB',
#   Mood=Sub|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin),
#  ('comentar',
#   'comentaren',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin),
#  ('seguir', 'seguireu', 'VERB', Mood=Imp|Number=Plur|Person=1|VerbForm=Fin),
#  ('guardar',
#   'guardaràs',
#   'VERB',
#   Mood=Sub|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin),
#  ('menció', 'menciones', 'NOUN', Gender=Fem|Number=Plur),
#  ('amagar', 'amagaria', 'VERB', Mood=Cnd|Number=Sing|Person=3|VerbForm=Fin),
#  ('comentar',
#   'comentat',
#   'VERB',
#   Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part),
#  ('denunciar',
#   'denunciarem',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=1|Tense=Fut|VerbForm=Fin),
#  ('seguir',
#   'seguissin',
#   'VERB',
#   Mood=Sub|Number=Plur|Person=3|Tense=Imp|VerbForm=Fin),
#  ('clavar',
#   'claven',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Imp|VerbForm=Fin),
#  ('guardar',
#   'guardava',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin),
#  ('enviar',
#   'enviessin',
#   'VERB',
#   Mood=Sub|Number=Plur|Person=3|Tense=Imp|VerbForm=Fin),
#  ('seguir', 'seguíem', 'VERB', Mood=Cnd|Number=Plur|Person=1|VerbForm=Fin),
#  ('clavar',
#   'clavaven',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Imp|VerbForm=Fin),
#  ('piular', 'piulant', 'VERB', VerbForm=Ger),
#  ('respondre',
#   'respon',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin),
#  ('publicar',
#   'publicau',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin),
#  ('clavar', 'clavaria', 'VERB', Mood=Cnd|Number=Sing|Person=3|VerbForm=Fin),
#  ('retuitejar', 'retuitejar', 'VERB', VerbForm=Inf),
#  ('compartir',
#   'compartia',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin),
#  ('enviar', 'envià', 'VERB', VerbForm=Inf),
#  ('ocultar',
#   'ocultaren',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin),
#  ('comentar',
#   'comentareu',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin),
#  ('bloquejar', 'bloquejant', 'VERB', VerbForm=Inf),
#  ('ocultar',
#   'ocultarà',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Fut|VerbForm=Fin),
#  ('esborrar',
#   'esborraven',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Imp|VerbForm=Fin),
#  ('clavar', 'clavés', 'VERB', VerbForm=Inf),
#  ('prohibir',
#   'prohibia',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin),
#  ('prohibir',
#   'prohibix',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Fut|VerbForm=Fin),
#  ('respondre',
#   'respondria',
#   'VERB',
#   Mood=Cnd|Number=Sing|Person=3|VerbForm=Fin),
#  ('ocultar',
#   'ocultés',
#   'VERB',
#   Mood=Sub|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin),
#  ('prohibir',
#   'prohibeixo',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin),
#  ('guardar',
#   'guardaren',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin),
#  ('seguir', 'seguir', 'VERB', VerbForm=Inf),
#  ('restringir', 'restringint', 'VERB', VerbForm=Ger),
#  ('comentar',
#   'comentàveu',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin),
#  ('compartir',
#   'compartim',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=1|Tense=Pres|VerbForm=Fin),
#  ('prohibir', 'prohibís', 'VERB', VerbForm=Inf),
#  ('notificació', 'notificació', 'NOUN', Gender=Fem|Number=Sing),
#  ('seguir',
#   'segueixin',
#   'VERB',
#   Mood=Sub|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin),
#  ('retuitar', 'retuitar', 'VERB', VerbForm=Inf),
#  ('seguir',
#   'seguís',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin),
#  ('silenciar',
#   'silenciaven',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Imp|VerbForm=Fin),
#  ('clavar',
#   'clavarà',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Fut|VerbForm=Fin),
#  ('denunciar',
#   'denunciam',
#   'VERB',
#   Mood=Sub|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin),
#  ('guardar',
#   'guardeu',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin),
#  ('guardar',
#   'guardarien',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Imp|VerbForm=Fin),
#  ('ocultar',
#   'ocultaran',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Fut|VerbForm=Fin),
#  ('prohibir',
#   'prohibeix',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin),
#  ('reenviar',
#   'reenvia',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin),
#  ('clavar', 'clavar', 'VERB', VerbForm=Inf),
#  ('piulada', 'piulada', 'NOUN', Gender=Fem|Number=Sing),
#  ('bloquejar',
#   'bloquejarà',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Fut|VerbForm=Fin),
#  ('publicar', 'publicant', 'VERB', VerbForm=Ger),
#  ('enviar',
#   'envieu',
#   'VERB',
#   Mood=Sub|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin),
#  ('repiular', 'repiulant', 'VERB', VerbForm=Ger),
#  ('denunciar',
#   'denuncií',
#   'VERB',
#   Mood=Sub|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin),
#  ('esborrar',
#   'esborrem',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=1|Tense=Fut|VerbForm=Fin),
#  ('reenviar', 'reenviar', 'VERB', VerbForm=Inf),
#  ('denunciar',
#   'denunciarà',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Fut|VerbForm=Fin),
#  ('restringir',
#   'restringia',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin),
#  ('prohibir', 'prohibint', 'VERB', VerbForm=Ger),
#  ('guardar',
#   'guardés',
#   'VERB',
#   Mood=Sub|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin),
#  ('comentar',
#   'comentés',
#   'VERB',
#   Mood=Sub|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin),
#  ('piular',
#   'piulem',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=1|Tense=Pres|VerbForm=Fin),
#  ('prohibir',
#   'prohibirà',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Fut|VerbForm=Fin),
#  ('comentar', 'comentéssiu', 'VERB', VerbForm=Inf),
#  ('silenciar', 'silenciant', 'VERB', VerbForm=Ger),
#  ('bloquejar', 'bloquejant', 'VERB', VerbForm=Ger),
#  ('guardar', 'guardant', 'VERB', VerbForm=Ger),
#  ('seguir',
#   'seguíssiu',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin),
#  ('reenviar',
#   'reenvio',
#   'VERB',
#   Mood=Sub|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin),
#  ('favorit', 'favorits', 'NOUN', Gender=Masc|Number=Plur),
#  ('silenciar',
#   'silenciaran',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Fut|VerbForm=Fin),
#  ('clavar',
#   'clavarem',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=1|Tense=Fut|VerbForm=Fin),
#  ('restringir',
#   'restringeixin',
#   'VERB',
#   Mood=Sub|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin),
#  ('compartir',
#   'compartiríem',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=1|Tense=Imp|VerbForm=Fin),
#  ('etiquetar', 'etiquetar', 'VERB', VerbForm=Inf),
#  ('missatge', 'missatge', 'NOUN', Gender=Masc|Number=Sing),
#  ('ocultar',
#   'oculten',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin),
#  ('guardar',
#   'guarden',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin),
#  ('repiular',
#   'repiulen',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin),
#  ('seguir',
#   'seguia',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin),
#  ('canal', 'canal', 'NOUN', Gender=Fem|Number=Sing),
#  ('blocar', 'blocar', 'VERB', VerbForm=Inf),
#  ('enviar', 'enviàs', 'VERB', VerbForm=Inf),
#  ('esborrar',
#   'esborrarà',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Fut|VerbForm=Fin),
#  ('piulet', 'piulet', 'NOUN', Gender=Masc|Number=Sing),
#  ('enviar', 'envieu', 'VERB', VerbForm=Inf),
#  ('publicar', 'publicar', 'VERB', VerbForm=Inf),
#  ('clavar',
#   'clava',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin),
#  ('restringir',
#   'restringeixi',
#   'VERB',
#   Mood=Sub|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin),
#  ('prohibir',
#   'prohibissin',
#   'VERB',
#   Mood=Sub|Number=Plur|Person=3|Tense=Imp|VerbForm=Fin),
#  ('guardar',
#   'guardàvem',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=1|Tense=Imp|VerbForm=Fin),
#  ('bloquejar', 'bloquejen', 'VERB', VerbForm=Inf),
#  ('bloquejar', 'bloquejar', 'VERB', VerbForm=Inf),
#  ('compartir',
#   'compartix',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin),
#  ('compartir',
#   'compartien',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Imp|VerbForm=Fin),
#  ('enviar',
#   'enviés',
#   'VERB',
#   Mood=Sub|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin),
#  ('comentar',
#   'comente',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin),
#  ('publicar',
#   'publicarà',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Fut|VerbForm=Fin),
#  ('etiqueta', 'etiquetes', 'NOUN', Gender=Fem|Number=Plur),
#  ('guardar',
#   'guardessin',
#   'VERB',
#   Mood=Sub|Number=Plur|Person=3|Tense=Imp|VerbForm=Fin),
#  ('seguir',
#   'seguíeu',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=1|Tense=Pres|VerbForm=Fin),
#  ('bloquejar',
#   'bloquege',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin),
#  ('comentar',
#   'comentaven',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Imp|VerbForm=Fin),
#  ('repiulet', 'repiulets', 'NOUN', Gender=Masc|Number=Plur),
#  ('respondre',
#   'respondreu',
#   'VERB',
#   Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part),
#  ('fil', 'fil', 'NOUN', Gender=Masc|Number=Sing),
#  ('comentar',
#   'comentava',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin),
#  ('seguir',
#   'seguiran',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Fut|VerbForm=Fin),
#  ('restringir',
#   'restringien',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Imp|VerbForm=Fin),
#  ('denunciar',
#   'denunciarien',
#   'VERB',
#   Mood=Cnd|Number=Plur|Person=3|VerbForm=Fin),
#  ('publicar',
#   'publicaríem',
#   'VERB',
#   Mood=Sub|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin),
#  ('seguir',
#   'seguiré',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=1|Tense=Fut|VerbForm=Fin),
#  ('clavar', 'clavo', 'VERB', VerbForm=Inf),
#  ('compartir',
#   'comparteixis',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin),
#  ('amagar',
#   'amagarem',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=1|Tense=Fut|VerbForm=Fin),
#  ('enviar',
#   'enviem',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=1|Tense=Pres|VerbForm=Fin),
#  ('enviar',
#   'enviïn',
#   'VERB',
#   Mood=Sub|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin),
#  ('respondre',
#   'respondràs',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin),
#  ('prohibir',
#   'prohibirien',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Imp|VerbForm=Fin),
#  ('piular',
#   'piulen',
#   'VERB',
#   Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin),
#  ('denunciar',
#   'denunciés',
#   'VERB',
#   Mood=Sub|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin),
#  ('compartir',
#   'compartesc',
#   'VERB',
#   Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin)]

# %%
# Create a DF from the list of tuples created previously
infl_df = pd.DataFrame(m, columns=['Lemma', 'Wordform', 'POS', 'Full_POS']).sort_values(by=['Lemma', 'Wordform'], axis=0, inplace=False).reset_index(drop=True)

# %%
infl_df[infl_df['Full_POS'].isna()]
# Out:
# Empty DataFrame
# Columns: [Lemma, Wordform, POS, Full_POS]
# Index: []

# %%
infl_df.head()
# Out:
#     Lemma Wordform   POS                                           Full_POS
# 0  amagar     amag  VERB  (Mood=Ind, Number=Sing, Person=3, Tense=Pres, ...
# 1  amagar    amaga  VERB  (Mood=Ind, Number=Sing, Person=3, Tense=Pres, ...
# 2  amagar   amagam  VERB  (Mood=Ind, Number=Sing, Person=3, Tense=Pres, ...
# 3  amagar  amagant  VERB                                     (VerbForm=Ger)
# 4  amagar   amagar  VERB                                     (VerbForm=Inf)

# %%
# Save DF to csv file
infl_df.to_csv('inflection_table_cat.csv', sep=';')
